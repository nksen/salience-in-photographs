# %% [markdown]
#  # Gaze maps and apti
#  Now we can test the results of the apti procedure by comparison
#  with the gaze maps we produced earlier.
#
#
#  First, we need to load the gaze maps and the apti results.
#  We also need to import all our apti modules

# %%
# %matplotlib inline
import os
import pickle
from pathlib import Path
import pandas as pd

import cv2
import matplotlib.pyplot as plt

import aptipy.analysis.utilities as utilities
from aptipy.apti import bounding_box, box_factory

# %%
# First get gazemaps (the easier bit)

folderpath = r'D:\Users\Naim\OneDrive\CloudDocs\UNIVERSITY\S8\MPhys_s8\eyetracking_analysis\gazemaps'
gazemaps_dict = dict()
for file in os.listdir(folderpath):
    img_name = utilities.remove_prefix(file, 'gazemap_')
    filepath = folderpath + '\\' + file
    gazemaps_dict[img_name] = cv2.imread(filepath, 0)

# %%
# Now we need to get all 180 different headline positions

toplevel_path = Path(
    r'D:\Users\Naim\OneDrive\CloudDocs\UNIVERSITY\S8\MPhys_s8\results\first_run'
)
boxes_dict = dict()
for img_name in gazemaps_dict:
    img_name_noext = Path(img_name).stem
    # remove ext
    midlevel_path = toplevel_path / Path(img_name).stem
    # Just in case something gets garbled between image names and folder names
    if midlevel_path.is_dir():
        pass
    else:
        raise OSError(str(midlevel_path), 'Does not exist.')

    # loop over the 9 box positions
    results_subdict = dict()
    pos_list = box_factory.positions_list()
    for pos in pos_list:
        # get baselevel path and construct filename
        baselevel_path = midlevel_path / pos
        metafile_name = 'metadata_' + pos + '_' + img_name_noext + '.pkl'

        with (baselevel_path / metafile_name).open('rb') as file:
            metafile = pickle.load(file)
        results_subdict[pos] = metafile

    boxes_dict[img_name] = results_subdict

# %% [markdown]
#  ##
#  With all the bits loaded, we now want to construct a gazebox and measure the
#  gaze density for each box position. Any invalid text positions will be discarded.
#  We store the results as a pandas dataframe.

# %%
results_df = pd.DataFrame(columns=['MediaName', 'BoxPosition', 'BoxGazeDensity', 'TotalGazeDensity'])
for img_name, gazemap in gazemaps_dict.items():
    for box_pos, metadata in boxes_dict[img_name].items():
        # temporary dictionary to store a row
        row_dict = {'MediaName': img_name, 'BoxPosition': box_pos}
        
        # get tl and dims to construct gaze box
        box_tl = [metadata.headline_tl[1], metadata.headline_tl[0]]
        box_dims = [
            metadata.headline_br[1] - metadata.headline_tl[1],
            metadata.headline_br[0] - metadata.headline_tl[0]
        ]

        # construct GazeBox
        try:
            from aptipy.apti.preprocessing import generate_saliency_map

            # load image and generate smap
            raw_img = cv2.imread(r'D:\Users\Naim\OneDrive\CloudDocs\UNIVERSITY\S8\MPhys_s8\test_images_2' + '\\' + img_name)

            smap = generate_saliency_map(raw_img)
            gazebox = utilities.GazeBox(gazemap, box_tl, box_dims)
            sbox = bounding_box.Box(smap, box_tl, box_dims)
            gazemap_with_overlay = gazebox.overlay_box(gazemap)

            # append to row dict
            row_dict['OrgBoxCost'] = metadata.cost_history[-1]
            row_dict['HeadlineCost'] = sbox.cost
            row_dict['BoxGazeDensity'] = gazebox.gaze_heat_density
            row_dict['TotalGazeDensity'] = gazebox.total_heat_density

        except:
            # append NaN to row if results are invalid
            row_dict['BoxGazeDensity'] = None
            row_dict['TotalGazeDensity'] = None
        results_df = results_df.append(row_dict, ignore_index=True)

results_df['FractionalGazeDensity'] = results_df['BoxGazeDensity'] / results_df['TotalGazeDensity']
with pd.option_context('display.max_rows',None):
    display(results_df)
# Out:
#                           MediaName BoxPosition  BoxGazeDensity  \
# 0                         boyce.jpg          tl       28.025296
# 1                         boyce.jpg          tr       18.434809
# 2                         boyce.jpg          bl       74.509992
# 3                         boyce.jpg          br       57.953384
# 4                         boyce.jpg           c       54.894821
# 5                         boyce.jpg          cl       97.383919
# 6                         boyce.jpg          cr       66.144033
# 7                         boyce.jpg          ct       17.141624
# 8                         boyce.jpg          cb       87.724054
# 9                    DiegoCosta.jpg          tl       30.183772
# 10                   DiegoCosta.jpg          tr       47.091659
# 11                   DiegoCosta.jpg          bl       34.800969
# 12                   DiegoCosta.jpg          br       47.565793
# 13                   DiegoCosta.jpg           c       30.291599
# 14                   DiegoCosta.jpg          cl       30.291599
# 15                   DiegoCosta.jpg          cr      154.015937
# 16                   DiegoCosta.jpg          ct       47.091659
# 17                   DiegoCosta.jpg          cb       49.975986
# 18                       dzeko2.jpg          tl       17.459527
# 19                       dzeko2.jpg          tr       45.653889
# 20                       dzeko2.jpg          bl       80.260706
# 21                       dzeko2.jpg          br      142.067832
# 22                       dzeko2.jpg           c       74.071208
# 23                       dzeko2.jpg          cl       20.878999
# 24                       dzeko2.jpg          cr       94.119790
# 25                       dzeko2.jpg          ct       22.037993
# 26                       dzeko2.jpg          cb       80.260706
# 27                  edmund body.jpg          tl       32.532047
# 28                  edmund body.jpg          tr       58.203984
# 29                  edmund body.jpg          bl      122.037137
# 30                  edmund body.jpg          br      117.324331
# 31                  edmund body.jpg           c      181.648681
# 32                  edmund body.jpg          cl       57.094756
# 33                  edmund body.jpg          cr       77.527364
# 34                  edmund body.jpg          ct       44.558592
# 35                  edmund body.jpg          cb      126.693613
# 36                   edmund_afp.jpg          tl       39.385160
# 37                   edmund_afp.jpg          tr       38.756037
# 38                   edmund_afp.jpg          bl       33.420408
# 39                   edmund_afp.jpg          br       98.434463
# 40                   edmund_afp.jpg           c       98.810463
# 41                   edmund_afp.jpg          cl       14.817623
# 42                   edmund_afp.jpg          cr       95.001559
# 43                   edmund_afp.jpg          ct       39.406309
# 44                   edmund_afp.jpg          cb       98.326163
# 45            eoin_morgan_getty.jpg          tl       39.171846
# 46            eoin_morgan_getty.jpg          tr             NaN
# 47            eoin_morgan_getty.jpg          bl      131.841186
# 48            eoin_morgan_getty.jpg          br      144.996046
# 49            eoin_morgan_getty.jpg           c       68.732971
# 50            eoin_morgan_getty.jpg          cl       39.171846
# 51            eoin_morgan_getty.jpg          cr             NaN
# 52            eoin_morgan_getty.jpg          ct       59.777332
# 53            eoin_morgan_getty.jpg          cb      171.999839
# 54                       etihad.PNG          tl       49.520647
# 55                       etihad.PNG          tr       16.969527
# 56                       etihad.PNG          bl      103.738890
# 57                       etihad.PNG          br       80.200792
# 58                       etihad.PNG           c      118.593842
# 59                       etihad.PNG          cl       87.633352
# 60                       etihad.PNG          cr       77.955295
# 122              MinMurrayfield.jpg          cl       95.336657
# 123              MinMurrayfield.jpg          cr      101.580153
# 124              MinMurrayfield.jpg          ct       59.874245
# 125              MinMurrayfield.jpg          cb      214.945250
# 126        Nathaniel_Wood_Getty.jpg          tl       59.464451
# 127        Nathaniel_Wood_Getty.jpg          tr       92.070216
# 128        Nathaniel_Wood_Getty.jpg          bl      114.416425
# 129        Nathaniel_Wood_Getty.jpg          br      147.605842
# 130        Nathaniel_Wood_Getty.jpg           c      133.387478
# 131        Nathaniel_Wood_Getty.jpg          cl      107.010062
# 132        Nathaniel_Wood_Getty.jpg          cr             NaN
# 133        Nathaniel_Wood_Getty.jpg          ct       74.892674
# 134        Nathaniel_Wood_Getty.jpg          cb      139.108239
# 135     peter_brackley_brighton.PNG          tl       15.405290
# 136     peter_brackley_brighton.PNG          tr       14.788120
# 137     peter_brackley_brighton.PNG          bl       27.449367
# 138     peter_brackley_brighton.PNG          br       45.534341
# 139     peter_brackley_brighton.PNG           c       16.653726
# 140     peter_brackley_brighton.PNG          cl             NaN
# 141     peter_brackley_brighton.PNG          cr       19.822834
# 142     peter_brackley_brighton.PNG          ct       31.132271
# 143     peter_brackley_brighton.PNG          cb       62.621754
# 144                 ronaldo_afp.jpg          tl       50.273421
# 145                 ronaldo_afp.jpg          tr       36.254507
# 146                 ronaldo_afp.jpg          bl       50.705265
# 147                 ronaldo_afp.jpg          br       92.578443
# 148                 ronaldo_afp.jpg           c       55.714884
# 149                 ronaldo_afp.jpg          cl       55.714884
# 150                 ronaldo_afp.jpg          cr       80.530587
# 151                 ronaldo_afp.jpg          ct       50.273421
# 152                 ronaldo_afp.jpg          cb       93.353926
# 153             rossiter549_sns.jpg          tl       69.046652
# 154             rossiter549_sns.jpg          tr       17.377823
# 155             rossiter549_sns.jpg          bl      165.180463
# 156             rossiter549_sns.jpg          br       17.599269
# 157             rossiter549_sns.jpg           c      144.785497
# 158             rossiter549_sns.jpg          cl      120.704113
# 159             rossiter549_sns.jpg          cr       45.092512
# 160             rossiter549_sns.jpg          ct       27.897697
# 161             rossiter549_sns.jpg          cb       45.567150
# 162                savea_toulon.jpg          tl       45.410972
# 163                savea_toulon.jpg          tr       77.661102
# 164                savea_toulon.jpg          bl       52.458877
# 165                savea_toulon.jpg          br      108.847925
# 166                savea_toulon.jpg           c      109.915473
# 167                savea_toulon.jpg          cl      121.669240
# 168                savea_toulon.jpg          cr      109.391680
# 169                savea_toulon.jpg          ct       45.410972
# 170                savea_toulon.jpg          cb      109.366848
# 171          Sergio_Perez_Getty.JPG          tl       10.240606
# 172          Sergio_Perez_Getty.JPG          tr       20.162690
# 173          Sergio_Perez_Getty.JPG          bl      112.559659
# 174          Sergio_Perez_Getty.JPG          br       73.921237
# 175          Sergio_Perez_Getty.JPG           c       10.240606
# 176          Sergio_Perez_Getty.JPG          cl       10.240606
# 177          Sergio_Perez_Getty.JPG          cr       38.925403
# 178          Sergio_Perez_Getty.JPG          ct       10.240606
# 179          Sergio_Perez_Getty.JPG          cb      136.385361
#
#      TotalGazeDensity  HeadlineCost  OrgBoxCost  FractionalGazeDensity
# 129         89.813758      0.597772    0.654810               1.643466
# 130         89.813758      1.208813    0.889026               1.485156
# 131         89.813758      0.636367    0.596200               1.191466
# 132               NaN           NaN         NaN                    NaN
# 133         89.813758      1.044069    1.025447               0.833866
# 134         89.813758      0.700074    0.787803               1.548852
# 135         30.290386      1.484408    0.773515               0.508587
# 136         30.290386      1.343334    1.049403               0.488212
# 137         30.290386      0.409186    0.359591               0.906207
# 138         30.290386      0.622134    0.679780               1.503261
# 139         30.290386      0.346517    0.167059               0.549802
# 140               NaN           NaN         NaN                    NaN
# 141         30.290386      0.302551    0.167059               0.654427
# 142         30.290386      1.377774    1.061030               1.027794
# 143         30.290386      0.636576    0.550821               2.067381
# 144         64.888631      0.257712    0.238258               0.774765
# 145         64.888631      0.472208    0.480403               0.558719
# 146         64.888631      0.291246    0.967915               0.781420
# 147         64.888631      1.369907    1.137226               1.426728
# 148         64.888631      0.244647    0.215165               0.858623
# 149         64.888631      0.244647    0.214462               0.858623
# 150         64.888631      0.631585    0.902113               1.241058
# 151         64.888631      0.257712    0.238330               0.774765
# 152         64.888631      1.381244    1.145390               1.438679
# 153         82.564749      0.127972    0.093115               0.836273
# 154         82.564749      0.394409    0.347828               0.210475
# 155         82.564749      0.712787    1.141738               2.000617
# 156         82.564749      0.394685    0.987823               0.213157
# 157         82.564749      0.761114    0.571723               1.753599
# 158         82.564749      0.576338    0.530102               1.461933
# 159         82.564749      0.328349    0.454339               0.546147
# 160         82.564749      0.517891    0.606846               0.337889
# 161         82.564749      0.527556    0.987994               0.551896
# 162         75.095580      0.762589    0.632413               0.604709
# 163         75.095580      1.070535    1.235655               1.034163
# 164         75.095580      1.495469    0.895931               0.698561
# 165         75.095580      1.201008    0.707823               1.449458
# 166         75.095580      1.214382    0.714357               1.463674
# 167         75.095580      1.453193    1.065299               1.620192
# 168         75.095580      1.203961    0.710176               1.456699
# 169         75.095580      0.762589    0.637713               0.604709
# 170         75.095580      1.211410    0.711980               1.456369
# 171         54.768178      0.251859    0.707482               0.186981
# 172         54.768178      0.770349    0.807119               0.368146
# 173         54.768178      0.837889    1.243324               2.055202
# 174         54.768178      0.816709    0.920617               1.349711
# 175         54.768178      0.251859    0.710609               0.186981
# 176         54.768178      0.251859    0.709902               0.186981
# 177         54.768178      0.786088    0.809437               0.710730
# 178         54.768178      0.251859    0.708184               0.186981
# 179         54.768178      1.112249    1.393182               2.490230

# %% [markdown]
#  ## Export and visualisation
#  Now export the dataframe for safekeeping.

# %%
savepath = r'D:\Users\Naim\OneDrive\CloudDocs\UNIVERSITY\S8\MPhys_s8\eyetracking_analysis\gazedata_results.xlsx'
results_df.to_excel(savepath)

# %% [markdown]
#  ## Boxes with lowest fractional gaze density

# %%
gaze_based_selection = results_df.loc[results_df.groupby(['MediaName'])['FractionalGazeDensity'].idxmin()]
hlcost_based_selection = results_df.loc[results_df.groupby(['MediaName'])['HeadlineCost'].idxmin()]
boxcost_based_selection = results_df.loc[results_df.groupby(['MediaName'])['OrgBoxCost'].idxmin()]

selection_overlap = pd.merge(gaze_based_selection, hlcost_based_selection, how='inner', on=['BoxGazeDensity'])
boxselection_overlap = pd.merge(gaze_based_selection, boxcost_based_selection, how='inner', on=['BoxGazeDensity'])

with pd.option_context('display.max_rows',None):
    display("gaze based selection", gaze_based_selection)
    display("box-cost based selection", boxcost_based_selection)
    display("headline-cost based selection", hlcost_based_selection)
    display("headline/gaze overlap", selection_overlap)
    display("box/gaze overlap", boxselection_overlap)
# Out:
# 'gaze based selection'
#                           MediaName BoxPosition  BoxGazeDensity  \
# 9                    DiegoCosta.jpg          tl       30.183772
# 79     GettyImages-09 australia.jpg          ct       28.147218
# 82   GettyImages-1052514534 (1).jpg          tr       21.748082
# 117              MinMurrayfield.jpg          tl       41.693582
# 126        Nathaniel_Wood_Getty.jpg          tl       59.464451
# 171          Sergio_Perez_Getty.JPG          tl       10.240606
# 7                         boyce.jpg          ct       17.141624
# 18                       dzeko2.jpg          tl       17.459527
# 27                  edmund body.jpg          tl       32.532047
# 41                   edmund_afp.jpg          cl       14.817623
# 45            eoin_morgan_getty.jpg          tl       39.171846
# 55                       etihad.PNG          tr       16.969527
# 64                 getty button.jpg          tr       36.730719
# 90                 hamitlom_afp.jpg          tl       18.752940
# 99               joe_root_getty.jpg          tl       55.036638
# 108         johanna_konta_getty.jpg          tl       53.766135
# 136     peter_brackley_brighton.PNG          tr       14.788120
# 145                 ronaldo_afp.jpg          tr       36.254507
# 154             rossiter549_sns.jpg          tr       17.377823
# 162                savea_toulon.jpg          tl       45.410972
#
#      TotalGazeDensity  HeadlineCost  OrgBoxCost  FractionalGazeDensity
# 9           85.889711      0.070798    0.038854               0.351425
# 79          67.628004      0.634954    0.431342               0.416207
# 82          66.730793      0.503639    0.485036               0.325908
# 117        108.508693      0.336440    0.267782               0.384242
# 126         89.813758      1.372666    1.097176               0.662086
# 171         54.768178      0.251859    0.707482               0.186981
# 7           43.433816      0.881143    0.951326               0.394661
# 18          55.251044      0.351086    0.304841               0.316004
# 27          70.818781      0.733834    0.673963               0.459370
# 41          50.987305      0.347727    0.124195               0.290614
# 45          74.234304      0.703330    0.706632               0.527678
# 55          52.227010      1.193949    0.743091               0.324919
# 64          88.839085      0.676647    0.649965               0.413452
# 90          60.715157      0.240101    0.205376               0.308868
# 99         116.705898      0.734158    0.480991               0.471584
# 108         73.255089      0.093509    0.061201               0.733958
# 136         30.290386      1.343334    1.049403               0.488212
# 145         64.888631      0.472208    0.480403               0.558719
# 154         82.564749      0.394409    0.347828               0.210475
# 162         75.095580      0.762589    0.632413               0.604709
# 'box-cost based selection'
#                           MediaName BoxPosition  BoxGazeDensity  \
# 13                   DiegoCosta.jpg           c       30.291599
# 78     GettyImages-09 australia.jpg          cr      102.622708
# 86   GettyImages-1052514534 (1).jpg          cl      102.174844
# 124              MinMurrayfield.jpg          ct       59.874245
# 131        Nathaniel_Wood_Getty.jpg          cl      107.010062
# 171          Sergio_Perez_Getty.JPG          tl       10.240606
# 6                         boyce.jpg          cr       66.144033
# 23                       dzeko2.jpg          cl       20.878999
# 32                  edmund body.jpg          cl       57.094756
# 41                   edmund_afp.jpg          cl       14.817623
# 45            eoin_morgan_getty.jpg          tl       39.171846
# 58                       etihad.PNG           c      118.593842
# 68                 getty button.jpg          cl       82.570247
# 94                 hamitlom_afp.jpg           c       19.008678
# 106              joe_root_getty.jpg          ct       92.969378
# 113         johanna_konta_getty.jpg          cl       56.408280
# 139     peter_brackley_brighton.PNG           c       16.653726
# 149                 ronaldo_afp.jpg          cl       55.714884
# 153             rossiter549_sns.jpg          tl       69.046652
# 162                savea_toulon.jpg          tl       45.410972
#
#      TotalGazeDensity  HeadlineCost  OrgBoxCost  FractionalGazeDensity
# 13          85.889711      0.070827    0.003597               0.352680
# 78          67.628004      0.334864    0.171590               1.517459
# 86          66.730793      1.022039    0.291974               1.531150
# 124        108.508693      0.291824    0.253000               0.551792
# 131         89.813758      0.636367    0.596200               1.191466
# 171         54.768178      0.251859    0.707482               0.186981
# 6           43.433816      1.041942    0.812418               1.522869
# 23          55.251044      0.175244    0.132707               0.377893
# 32          70.818781      0.756410    0.656538               0.806209
# 41          50.987305      0.347727    0.124195               0.290614
# 45          74.234304      0.703330    0.706632               0.527678
# 58          52.227010      0.426340    0.474108               2.270738
# 68          88.839085      0.382539    0.210279               0.929436
# 94          60.715157      0.240189    0.072713               0.313080
# 106        116.705898      0.432832    0.306994               0.796613
# 113         73.255089      0.116252    0.046946               0.770025
# 139         30.290386      0.346517    0.167059               0.549802
# 149         64.888631      0.244647    0.214462               0.858623
# 153         82.564749      0.127972    0.093115               0.836273
# 162         75.095580      0.762589    0.632413               0.604709
# 'headline-cost based selection'
#                           MediaName BoxPosition  BoxGazeDensity  \
# 17                   DiegoCosta.jpg          cb       49.975986
# 78     GettyImages-09 australia.jpg          cr      102.622708
# 88   GettyImages-1052514534 (1).jpg          ct       27.481162
# 124              MinMurrayfield.jpg          ct       59.874245
# 129        Nathaniel_Wood_Getty.jpg          br      147.605842
# 171          Sergio_Perez_Getty.JPG          tl       10.240606
# 7                         boyce.jpg          ct       17.141624
# 23                       dzeko2.jpg          cl       20.878999
# 27                  edmund body.jpg          tl       32.532047
# 41                   edmund_afp.jpg          cl       14.817623
# 49            eoin_morgan_getty.jpg           c       68.732971
# 58                       etihad.PNG           c      118.593842
# 65                 getty button.jpg          bl       72.964804
# 91                 hamitlom_afp.jpg          tr       24.316316
# 107              joe_root_getty.jpg          cb      113.548709
# 108         johanna_konta_getty.jpg          tl       53.766135
# 141     peter_brackley_brighton.PNG          cr       19.822834
# 148                 ronaldo_afp.jpg           c       55.714884
# 153             rossiter549_sns.jpg          tl       69.046652
# 162                savea_toulon.jpg          tl       45.410972
#
#      TotalGazeDensity  HeadlineCost  OrgBoxCost  FractionalGazeDensity
# 17          85.889711      0.050287    0.208086               0.581862
# 78          67.628004      0.334864    0.171590               1.517459
# 88          66.730793      0.498062    0.468737               0.411821
# 124        108.508693      0.291824    0.253000               0.551792
# 129         89.813758      0.597772    0.654810               1.643466
# 171         54.768178      0.251859    0.707482               0.186981
# 7           43.433816      0.881143    0.951326               0.394661
# 23          55.251044      0.175244    0.132707               0.377893
# 27          70.818781      0.733834    0.673963               0.459370
# 41          50.987305      0.347727    0.124195               0.290614
# 49          74.234304      0.492005    0.748748               0.925892
# 58          52.227010      0.426340    0.474108               2.270738
# 65          88.839085      0.337251    0.734131               0.821314
# 91          60.715157      0.201247    0.179140               0.400498
# 107        116.705898      0.282816    0.654407               0.972947
# 108         73.255089      0.093509    0.061201               0.733958
# 141         30.290386      0.302551    0.167059               0.654427
# 148         64.888631      0.244647    0.215165               0.858623
# 153         82.564749      0.127972    0.093115               0.836273
# 162         75.095580      0.762589    0.632413               0.604709
# 'headline/gaze overlap'
#                MediaName_x BoxPosition_x  BoxGazeDensity  TotalGazeDensity_x  \
# 0   Sergio_Perez_Getty.JPG            tl       10.240606           54.768178
# 1                boyce.jpg            ct       17.141624           43.433816
# 2          edmund body.jpg            tl       32.532047           70.818781
# 3           edmund_afp.jpg            cl       14.817623           50.987305
# 4  johanna_konta_getty.jpg            tl       53.766135           73.255089
# 5         savea_toulon.jpg            tl       45.410972           75.095580
#
#    HeadlineCost_x  OrgBoxCost_x  FractionalGazeDensity_x  \
# 0        0.251859      0.707482                 0.186981
# 1        0.881143      0.951326                 0.394661
# 2        0.733834      0.673963                 0.459370
# 3        0.347727      0.124195                 0.290614
# 4        0.093509      0.061201                 0.733958
# 5        0.762589      0.632413                 0.604709
#
#                MediaName_y BoxPosition_y  TotalGazeDensity_y  HeadlineCost_y  \
# 0   Sergio_Perez_Getty.JPG            tl           54.768178        0.251859
# 1                boyce.jpg            ct           43.433816        0.881143
# 2          edmund body.jpg            tl           70.818781        0.733834
# 3           edmund_afp.jpg            cl           50.987305        0.347727
# 4  johanna_konta_getty.jpg            tl           73.255089        0.093509
# 5         savea_toulon.jpg            tl           75.095580        0.762589
#
#    OrgBoxCost_y  FractionalGazeDensity_y
# 0      0.707482                 0.186981
# 1      0.951326                 0.394661
# 2      0.673963                 0.459370
# 3      0.124195                 0.290614
# 4      0.061201                 0.733958
# 5      0.632413                 0.604709
# 'box/gaze overlap'
#               MediaName_x BoxPosition_x  BoxGazeDensity  TotalGazeDensity_x  \
# 0  Sergio_Perez_Getty.JPG            tl       10.240606           54.768178
# 1          edmund_afp.jpg            cl       14.817623           50.987305
# 2   eoin_morgan_getty.jpg            tl       39.171846           74.234304
# 3        savea_toulon.jpg            tl       45.410972           75.095580
#
#    HeadlineCost_x  OrgBoxCost_x  FractionalGazeDensity_x  \
# 0        0.251859      0.707482                 0.186981
# 1        0.347727      0.124195                 0.290614
# 2        0.703330      0.706632                 0.527678
# 3        0.762589      0.632413                 0.604709
#
#               MediaName_y BoxPosition_y  TotalGazeDensity_y  HeadlineCost_y  \
# 0  Sergio_Perez_Getty.JPG            tl           54.768178        0.251859
# 1          edmund_afp.jpg            cl           50.987305        0.347727
# 2   eoin_morgan_getty.jpg            tl           74.234304        0.703330
# 3        savea_toulon.jpg            tl           75.095580        0.762589
#
#    OrgBoxCost_y  FractionalGazeDensity_y
# 0      0.707482                 0.186981
# 1      0.124195                 0.290614
# 2      0.706632                 0.527678
# 3      0.632413                 0.604709
